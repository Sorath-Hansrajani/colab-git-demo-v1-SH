# %% [markdown]
# <a href="https://colab.research.google.com/github/Sorath-Hansrajani/colab-git-demo-v1-SH/blob/main/git_github_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Git and GitHub Exercise
# This notebook demonstrates basic Git operations

# %%
def greet(name):
    return f"Hello, {name}! Welcome to Git and GitHub."

print(greet("Sorath"))
# Out:
# Hello, Sorath! Welcome to Git and GitHub.

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
def calculate_square(number):
    return number ** 2

print(calculate_square(5))
